# %%
import pandas as pd
import numpy as np
df = pd.read_csv("DataZinto.csv", sep=";")
df
# Out:
#              Chips           Quantity  Selling Price  Stock Price
# 0            Simba                 10           16.0           14
# 1             Lays                 10           18.0           16
# 2          Doritos                 10           17.5           15
# 3         Pringles                 10           21.0           18
# 4           Stylos                 10            5.5            3
# 5              NaN                NaN            NaN          NaN
# 6        Chocolate           Quantity  Selling Price   Cost Price
# 7        Lunch Bar                 15           10.0          8.0
# 8             Aero                 15            9.5          7.0
# 9          Kit-cat                 15           15.0         13.0
# 10             Tex                 15            8.5          6.0
# 11       Milky Bar                 15            9.0          5.5
# 12             NaN                NaN            NaN          NaN
# ...
